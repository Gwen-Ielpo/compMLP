# %%
# !pip install netCDF4
# !pip install keras-rectified-adam
# !pip install kornia
import itertools

from scipy import linalg
import matplotlib.pyplot as plt 
import matplotlib as mpl



import netCDF4
from netCDF4 import Dataset
import pathlib


import numpy as np
import pandas as pd
import seaborn as sns

import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torch.utils.data import Dataset, DataLoader

import xarray as xr

from datetime import date
import datetime
import kornia
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.6/dist-packages (1.5.3)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.18.4)
# Requirement already satisfied: cftime in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.1.3)
# Requirement already satisfied: keras-rectified-adam in /usr/local/lib/python3.6/dist-packages (0.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-rectified-adam) (1.18.4)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-rectified-adam) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (3.13)
# Requirement already satisfied: kornia in /usr/local/lib/python3.6/dist-packages (0.3.1)
# Requirement already satisfied: torch==1.5.0 in /usr/local/lib/python3.6/dist-packages (from kornia) (1.5.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from kornia) (1.18.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.0->kornia) (0.16.0)

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor
from time import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import QuantileTransformer
from sklearn.pipeline import make_pipeline

from sklearn.inspection import partial_dependence
from sklearn.inspection import plot_partial_dependence
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn import mixture
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler


# !pip install skorch
from skorch import NeuralNetClassifier
from sklearn.model_selection import cross_val_score
# Out:
# Requirement already satisfied: skorch in /usr/local/lib/python3.6/dist-packages (0.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from skorch) (1.18.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from skorch) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from skorch) (1.4.1)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.6/dist-packages (from skorch) (4.41.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from skorch) (0.8.7)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.19.1->skorch) (0.15.1)

# %% [markdown]
# # Load the dataset (2004 period)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ds = xr.open_dataset("/content/gdrive/My Drive/dataset/SST_SSH_U_V_SLA_global_2004.nc")
print(ds.sizes)
ds
# Out:
# Frozen(SortedKeysDict({'lon': 1440, 'lat': 720, 'time': 366}))
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 366)
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Data variables:
#     SST      (time, lat, lon) float32 ...
#     SSH      (time, lon, lat) float32 ...
#     U        (time, lon, lat) float32 ...
#     V        (time, lon, lat) float32 ...
#     SLA      (time, lon, lat) float32 ...
# Attributes:
#     CDI:                    Climate Data Interface version 1.5.3 (http://code...
#     Conventions:            CF-1.0
#     history:                Mon Jul 21 17:26:58 2014: cdo merge SST_SSH_U_V_g...
#     title:                  Analysed foundation sea surface temperature, global
#     DSD_entry_id:           REMSS-L4LRfnd-GLOB-tmi_amsre_OI
#     references:             none
#     source_data:            TMI-REMSS,AMSRE-REMSS
#     contact:                support@remss.com
#     GDS_version_id:         GDS-v1.0-rev1.6
#     netcdf_version_id:      3.5.0
#     creation_date:          2010-08-04
#     product_version:        v03
#     spatial_resolution:     25 km
#     start_date:             2003-12-30
#     start_time:             00:00:00 UTC
#     stop_date:              2004-01-03
#     stop_time:              23:59:59 UTC
#     southernmost_latitude:  -89.875
#     northernmost_latitude:  89.875
#     westernmost_longitude:  -179.875
#     easternmost_longitude:  179.875
#     file_quality_index:     1
#     comment:                www.remss.com for more infomation on product
#     CDO:                    Climate Data Operators version 1.5.3 (http://code...

# %% [markdown]
# ## Definition of the time window and the region

# %%
time_window = 120

ds_cut = ds.sel(lon=slice(30,42),lat=slice(-48,-30))
ds_cut = ds_cut.isel(time=slice(0,time_window))
SSH = ds_cut.SSH.transpose('time','lat','lon')
SSH[0].plot()
SSH
# Out:
# <xarray.DataArray 'SSH' (time: 120, lat: 72, lon: 48)>
# [414720 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 30.125 30.375 30.625 30.875 ... 41.375 41.625 41.875
#   * lat      (lat) float32 -47.875 -47.625 -47.375 ... -30.625 -30.375 -30.125
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 2004-04-29T12:00:00
# Attributes:
#     long_name:        H
#     units:            cm
#     _CoordinateAxes:  time NbLongitudes NbLatitudes

# %% [markdown]
# ### Plot SST

# %%
SST = ds_cut.SST
SST[0].plot()

# %% [markdown]
# ### Plot SSH

# %%
SSH[110].plot()

# %% [markdown]
# ### Plot current U V

# %%
U = ds_cut.U.transpose('time','lat','lon')
V = ds_cut.V.transpose('time','lat','lon')
UV = U + V
UV[0].plot()

# %% [markdown]
# ### Computation of the min/max of all the variable for normalization

# %%
df = ds_cut.to_dataframe()
SST_x_max = df.SST.describe(include='all').loc['max']
SST_x_min = df.SST.describe(include='all').loc['min']
SSH_x_max = df.SSH.describe(include='all').loc['max']
SSH_x_min = df.SSH.describe(include='all').loc['min']
U_x_max = df.U.describe(include='all').loc['max']
U_x_min = df.U.describe(include='all').loc['min']
V_x_max = df.V.describe(include='all').loc['max']
V_x_min = df.V.describe(include='all').loc['min']
df.describe()
# Out:
#                  SST            SSH  ...              V            SLA
# count  405000.000000  414120.000000  ...  413640.000000  414720.000000
# mean      290.646210      68.459991  ...       0.222889       6.277696
# std         6.365062      54.519394  ...      25.368128      19.130518
# min       276.750000     -62.506332  ...    -156.930954     -83.590195
# 25%       284.399994      12.988934  ...      -7.640310      -2.466063
# 50%       293.100006      83.187851  ...       0.802993       4.450123
# 75%       295.949982     118.468697  ...       9.747392      13.739470
# max       302.100006     199.925827  ...     120.398727      89.636559
#
# [8 rows x 5 columns]

# %%
for v in ds_cut.data_vars:
    print('{:>10}: {}'.format(v, ds[v].attrs['long_name']))
# Out:
#        SST: analysed sea surface temperature
#        SSH: H
#          U: U
#          V: V
#        SLA: H

# %% [markdown]
# #Normalization

# %%
def pad_with(vector, pad_width, iaxis, kwargs):
  pad_value = kwargs.get('padder', 10)
  vector[:pad_width[0]] = pad_value
  vector[-pad_width[1]:] = pad_value

def normalize_negative_one(img):
    normalized_input = (img - np.amin(img)) / (np.amax(img) - np.amin(img))
    return 2*normalized_input - 1

# %%
from sklearn.feature_extraction import image


#fill NaN values with the mean of the SSH, SST, U, V mean
SSTf = SST.fillna(SST.mean())
#SSTf = np.pad(SSTf, padding, pad_with, padder=SSTf.mean())
print('SST shape: {}'.format(SSTf.shape))


SSHf = SSH.fillna(SSH.mean())
print('SSH shape: {}'.format(SSHf.shape))

Uf = U.fillna(U.mean())
print('U shape: {}'.format(Uf.shape))

Vf = V.fillna(V.mean())
print('V shape: {}'.format(Vf.shape))

SST_n = np.empty(([time_window, 72,48]))
SSH_n = np.empty(([time_window, 72,48]))
U_n = np.empty(([time_window, 72,48]))
V_n = np.empty(([time_window, 72,48]))
#for each time step, compute patches of size (13x13), flatten them in 1D and concatenate them in SSH_patches, SST_patches, U_patches, V_patches
#output : 1D array of SSH patchs
for i in range(ds_cut.time.shape[0]):
  if (i%50 == 0):
    print("Round : "+ str(i))
  
  #print(SSH.shape[0])
  #for h in range(SSH[0].shape[0]):
  SSH_n[i] = (SSHf[i] - SSH_x_min)/(SSH_x_max-SSH_x_min)
  U_n[i] = (Uf[i] - U_x_min)/(U_x_max-U_x_min)
  V_n[i] = (Vf[i] - V_x_min)/(V_x_max-V_x_min)
  SST_n[i] = (SSTf[i] - SST_x_min)/(SST_x_max-SST_x_min)
  

  #print("SST " + str(SST[i].shape))
# Out:
# SST shape: (120, 72, 48)
# SSH shape: (120, 72, 48)
# U shape: (120, 72, 48)
# V shape: (120, 72, 48)
# Round : 0
# Round : 50
# Round : 100

# %% [markdown]
# ## Definition of the function that evaluate the accuracy of the model on a dataset

# %%
def calculate_accuracy(Y_hat, Y):
    _, Y_hat = Y_hat.max(1)
    print("Y : " + str(Y.shape))
    print("Y_hat : " + str(Y_hat.shape))
    trues = (Y_hat == Y[:,0,:,:].long()) * 1
    trues = trues.cpu().numpy()

    accuracy = np.mean(trues)

    return accuracy, Y_hat.cpu().numpy(), Y.cpu().numpy()


def evaluate_set(model, data_loader, set_name):
    model.eval()

    average_accuracy = 0
    n_samples = 0

    y_true = []
    y_pred = []

    for batch_idx, batch in enumerate(data_loader):
        print(str(batch_idx) + " / " + str(len(data_loader)))
        X = batch[0]
        Y = batch[1]

        batch_size = Y.shape[0]
        n_samples += batch_size

        out = model(X)

        accuracy, Y_hat, Y = calculate_accuracy(out, Y)
        average_accuracy += accuracy * batch_size

        y_true.append(Y)
        y_pred.append(Y_hat)

    return average_accuracy / n_samples, y_true, y_pred

# %% [markdown]
# ## Definition of the model

# %%
class ConvNet(torch.nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = torch.nn.Sequential(torch.nn.Conv2d(3, 3, kernel_size=3, stride=1, dilation = 1, padding=1))
        self.cnn_layers = Sequential(
            # Defining a 2D convolution layer
            torch.nn.Conv2d(3, 3, kernel_size=3, stride=1, dilation = 1, padding=1),
            ReLU(inplace=True)
        )

        
    def forward(self, x):
      out1 = self.layer1(x)
      #out1 = self.cnn_layers(x)
      #out2 = self.fc1(out1)
      return out1

# %% [markdown]
# # Data pre-processing and training

# %%
#X = np.stack((SST_patches,SSH, U, V))
X= SST_n
print(X[0].shape)

BATCH_SIZE = 90

print("U : " + str(U_n.shape))
print("V : " + str(V_n.shape))
print("SSH : " + str(SSH_n.shape))
y = np.stack((SSH_n, U_n, V_n)) 
y_nb_feature = y.shape[0]
#print magique
print(SST.shape[2])

y = y.reshape((time_window, SSH_n.shape[1], SSH_n.shape[2],y_nb_feature))
print("Y shape :" + str(y.shape))
# Split the data into training/validation/testing sets
X_train_np_1 = X[:90]
X_train_np = X[:70]
X_val_np = X[-20:]
X_test_np = X[-30:]
#X_train_rsp = X_train_np.reshape((190, 1, 72, 48))


#Reshaping and extension of the dimension from 1 to 3

X_train_exp = np.expand_dims(X_train_np,1)
X_train_dup = torch.from_numpy(X_train_exp).double()
X_train = X_train_dup.repeat(1,3,1,1)

X_val_exp = np.expand_dims(X_val_np,1)
X_val_dup = torch.from_numpy(X_val_exp).double()
X_val = X_val_dup.repeat(1,3,1,1)

X_test_exp = np.expand_dims(X_test_np,1)
X_test_dup = torch.from_numpy(X_test_exp).double()
X_test = X_test_dup.repeat(1,3,1,1)

print(type(X_train))
# Split the targets into training/validation/testing sets
y_train_np_1 = y[:90]
y_train_np = y_train_np_1[:70]
y_val_np = y[-20:]
y_test_np = y[-30:]

#Reshaping

y_train_rp = y_train_np.reshape((70, 3, 72, 48))
y_val_rp = y_val_np.reshape((20, 3, 72, 48))
y_test_rp = y_test_np.reshape((30, 3, 72, 48))

y_train = torch.from_numpy(y_train_rp).double()
y_val = torch.from_numpy(y_val_rp).double()
y_test = torch.from_numpy(y_test_rp).double()

#train = torch.utils.data.TensorDataset(X_train,y_train)

train_loader = DataLoader([X_train,y_train], batch_size=70, shuffle=True)
val_loader = DataLoader([X_val,y_val], batch_size=20, shuffle=True)
test_loader = DataLoader([X_test,y_test], batch_size=30, shuffle=False)

print("X_train : " + str(X_train.shape))
print("y_train : " + str(y_train.shape))
print("X_val : " + str(X_val.shape))
print("y_val : " + str(y_val.shape))
print("X_test : " + str(X_test.shape))
print("y_test : " + str(y_test.shape))


# Hyperparameters
num_epochs = 50
batch_size = 70
learning_rate = 0.01


#torch.manual_seed(RANDOM_SEED)

model = ConvNet()
model = model.double()

# Loss and optimizer
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

total_step = len(train_loader)
loss_list = []
acc_list = []
lap_list = []
val_list = []
for epoch in range(num_epochs):
  running_loss = 0.0
  running_lap = 0.0
  print("Epoch : " + str(epoch))
  for i, (images, labels) in enumerate(train_loader):
    # Run the forward pass
    print(images.type())
    print(labels.type())
    outputs = model(images)
    print("output : " + str(outputs.shape))
    print("labels : " + str(labels.shape))
    loss = torch.sqrt(criterion(outputs, labels))

    lap_out = kornia.filters.laplacian(outputs,3)
    lap_lab = kornia.filters.laplacian(labels,3)
    lap = torch.sqrt(criterion(lap_out, lap_lab))

    loss_list.append(loss.item())
    lap_list.append(lap)

    # Backprop and perform Adam optimisation
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    running_lap += lap
    if i % 90 == 0: 
      print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss ))
      print('laplacian : ' + str(running_lap))
      plt.figure()
      plt.title('Prediction Train')
      plt.imshow(torch.exp(outputs[0,2,:,:]).detach().cpu(), label='OUTPUT')
      running_loss = 0.0

      with torch.no_grad():
            validation_accuracy, _, _ = evaluate_set(model,
                                                     val_loader,
                                                     "VAL")
      print("validation accuracy :" + str(validation_accuracy))
      val_list.append(validation_accuracy)
# Out:
# (72, 48)
# U : (120, 72, 48)
# V : (120, 72, 48)
# SSH : (120, 72, 48)
# 48
# Y shape :(120, 72, 48, 3)
# <class 'torch.Tensor'>
# X_train : torch.Size([70, 3, 72, 48])
# y_train : torch.Size([70, 3, 72, 48])
# X_val : torch.Size([20, 3, 72, 48])
# y_val : torch.Size([20, 3, 72, 48])
# X_test : torch.Size([30, 3, 72, 48])
# y_test : torch.Size([30, 3, 72, 48])
# Epoch : 0
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [1,     1] loss: 0.424
# laplacian : tensor(0.0262, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.04380787037037037
# Epoch : 1
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [2,     1] loss: 0.331
# laplacian : tensor(0.0247, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9489438657407409
# Epoch : 2
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [3,     1] loss: 0.225
# laplacian : tensor(0.0277, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7821903935185185
# Epoch : 3
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [4,     1] loss: 0.193
# laplacian : tensor(0.0266, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.20996817129629627
# Epoch : 4
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [5,     1] loss: 0.230
# laplacian : tensor(0.0245, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.029658564814814815
# Epoch : 5
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [6,     1] loss: 0.220
# laplacian : tensor(0.0256, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.01880787037037037
# Epoch : 6
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [7,     1] loss: 0.232
# laplacian : tensor(0.0258, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.015162037037037035
# Epoch : 7
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [8,     1] loss: 0.240
# laplacian : tensor(0.0251, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.015306712962962963
# Epoch : 8
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [9,     1] loss: 0.234
# laplacian : tensor(0.0253, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.016435185185185185
# Epoch : 9
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [10,     1] loss: 0.224
# laplacian : tensor(0.0257, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.018995949074074075
# Epoch : 10
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [11,     1] loss: 0.215
# laplacian : tensor(0.0260, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.021339699074074073
# Epoch : 11
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [12,     1] loss: 0.209
# laplacian : tensor(0.0263, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.02696759259259259
# Epoch : 12
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [13,     1] loss: 0.207
# laplacian : tensor(0.0263, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.5107349537037037
# Epoch : 13
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [14,     1] loss: 0.209
# laplacian : tensor(0.0261, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8350405092592592
# Epoch : 14
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [15,     1] loss: 0.213
# laplacian : tensor(0.0258, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8690248842592594
# Epoch : 15
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [16,     1] loss: 0.216
# laplacian : tensor(0.0254, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9578414351851852
# Epoch : 16
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [17,     1] loss: 0.224
# laplacian : tensor(0.0259, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8162760416666666
# Epoch : 17
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [18,     1] loss: 0.217
# laplacian : tensor(0.0241, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9352719907407409
# Epoch : 18
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [19,     1] loss: 0.216
# laplacian : tensor(0.0234, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.673191550925926
# Epoch : 19
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [20,     1] loss: 0.213
# laplacian : tensor(0.0232, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.1739872685185185
# Epoch : 20
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [21,     1] loss: 0.173
# laplacian : tensor(0.0236, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.024797453703703703
# Epoch : 21
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [22,     1] loss: 0.171
# laplacian : tensor(0.0232, dtype=torch.float64, grad_fn=<AddBackward0>)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:121: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.03353587962962963
# Epoch : 22
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [23,     1] loss: 0.224
# laplacian : tensor(0.0224, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.020804398148148148
# Epoch : 23
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [24,     1] loss: 0.229
# laplacian : tensor(0.0222, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.03297164351851852
# Epoch : 24
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [25,     1] loss: 0.225
# laplacian : tensor(0.0223, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.03334780092592592
# Epoch : 25
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [26,     1] loss: 0.217
# laplacian : tensor(0.0226, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.02333622685185185
# Epoch : 26
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [27,     1] loss: 0.208
# laplacian : tensor(0.0231, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.02378472222222222
# Epoch : 27
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [28,     1] loss: 0.203
# laplacian : tensor(0.0236, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.026678240740740745
# Epoch : 28
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [29,     1] loss: 0.219
# laplacian : tensor(0.0243, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.653660300925926
# Epoch : 29
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [30,     1] loss: 0.201
# laplacian : tensor(0.0239, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.719212962962963
# Epoch : 30
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [31,     1] loss: 0.202
# laplacian : tensor(0.0236, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.929933449074074
# Epoch : 31
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [32,     1] loss: 0.213
# laplacian : tensor(0.0233, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7412181712962963
# Epoch : 32
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [33,     1] loss: 0.196
# laplacian : tensor(0.0224, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7200520833333334
# Epoch : 33
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [34,     1] loss: 0.175
# laplacian : tensor(0.0213, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8793113425925926
# Epoch : 34
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [35,     1] loss: 0.162
# laplacian : tensor(0.0201, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.5323640046296296
# Epoch : 35
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [36,     1] loss: 0.162
# laplacian : tensor(0.0193, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.10698784722222224
# Epoch : 36
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [37,     1] loss: 0.268
# laplacian : tensor(0.0192, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.024146412037037036
# Epoch : 37
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [38,     1] loss: 0.271
# laplacian : tensor(0.0192, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.021050347222222224
# Epoch : 38
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [39,     1] loss: 0.264
# laplacian : tensor(0.0195, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.020052083333333335
# Epoch : 39
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [40,     1] loss: 0.249
# laplacian : tensor(0.0201, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.019444444444444445
# Epoch : 40
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [41,     1] loss: 0.180
# laplacian : tensor(0.0206, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.019212962962962963
# Epoch : 41
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [42,     1] loss: 0.219
# laplacian : tensor(0.0213, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.020775462962962964
# Epoch : 42
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [43,     1] loss: 0.208
# laplacian : tensor(0.0218, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.03411458333333333
# Epoch : 43
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [44,     1] loss: 0.202
# laplacian : tensor(0.0222, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.10279224537037038
# Epoch : 44
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [45,     1] loss: 0.227
# laplacian : tensor(0.0220, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8135561342592592
# Epoch : 45
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [46,     1] loss: 0.204
# laplacian : tensor(0.0224, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7018373842592592
# Epoch : 46
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [47,     1] loss: 0.206
# laplacian : tensor(0.0222, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7374131944444444
# Epoch : 47
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [48,     1] loss: 0.209
# laplacian : tensor(0.0219, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.757421875
# Epoch : 48
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [49,     1] loss: 0.219
# laplacian : tensor(0.0207, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9324797453703704
# Epoch : 49
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [50,     1] loss: 0.198
# laplacian : tensor(0.0200, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7474247685185185

# %% [markdown]
# ## Plot of the prediction, the input, the label, the loss (RMSE), the cross validation and the RMSE of the laplacian

# %%
print(outputs[0,0,:,:])
plt.figure()
plt.title('Prediction Train')
plt.imshow(torch.exp(outputs[0,0,:,:]).detach().cpu(), label='OUTPUT')
#plt.clim(-3, 3)
plt.colorbar(label = 'SSH value')
plt.figure()
plt.title('Input Train')
plt.imshow(torch.exp(images[0,0,:,:]).detach().cpu(), label='OUTPUT')
#plt.clim(-3, 3)
plt.colorbar(label = 'SSH value')
plt.figure()
plt.title('Label Train')
plt.imshow(torch.exp(y_train[0,0,:,:]).detach().cpu(), label='LABEL') 
#plt.clim(-3, 3)
plt.colorbar(label = 'SSH value')
plt.figure()
plt.title('RMSE Loss')
plt.plot(np.array(loss_list), 'r')

plt.figure()
plt.title('Validation Set Accuracy')
plt.plot(np.array(val_list), 'r')

plt.figure()
plt.title('Laplacian')
plt.plot(np.array(lap_list), 'r')
# Out:
# tensor([[0.2457, 0.2335, 0.2321,  ..., 0.1876, 0.1940, 0.1676],
#         [0.2936, 0.2821, 0.2756,  ..., 0.2094, 0.2196, 0.1817],
#         [0.2983, 0.2839, 0.2731,  ..., 0.2188, 0.2322, 0.1865],
#         ...,
#         [0.6690, 0.6685, 0.6685,  ..., 0.8864, 0.8921, 0.4313],
#         [0.6690, 0.6685, 0.6685,  ..., 0.8891, 0.8943, 0.4309],
#         [0.5771, 0.5982, 0.5982,  ..., 0.7919, 0.7961, 0.4353]],
#        dtype=torch.float64, grad_fn=<SliceBackward>)

# %% [markdown]
# ### Compute the accuracy of the model on the test set

# %%
with torch.no_grad():
      validation_accuracy, _, _ = evaluate_set(model,test_loader,"VAL")
      print("validation accuracy :" + str(validation_accuracy))
# Out:
# 0 / 1
# Y : torch.Size([30, 3, 72, 48])
# Y_hat : torch.Size([30, 72, 48])
# validation accuracy :0.7547453703703704
