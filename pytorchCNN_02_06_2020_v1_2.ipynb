# %%
# !pip install netCDF4
# !pip install keras-rectified-adam
# !pip install kornia
import itertools

from scipy import linalg
import matplotlib.pyplot as plt 
import matplotlib as mpl



import netCDF4
from netCDF4 import Dataset
import pathlib


import numpy as np
import pandas as pd
import seaborn as sns

import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torch.utils.data import Dataset, DataLoader

import xarray as xr

from datetime import date
import datetime
import kornia
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.6/dist-packages (1.5.3)
# Requirement already satisfied: cftime in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.1.3)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.18.4)
# Requirement already satisfied: keras-rectified-adam in /usr/local/lib/python3.6/dist-packages (0.17.0)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-rectified-adam) (2.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-rectified-adam) (1.18.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.12.0)
# Requirement already satisfied: kornia in /usr/local/lib/python3.6/dist-packages (0.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from kornia) (1.18.4)
# Requirement already satisfied: torch==1.5.0 in /usr/local/lib/python3.6/dist-packages (from kornia) (1.5.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.0->kornia) (0.16.0)

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor
from time import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import QuantileTransformer
from sklearn.pipeline import make_pipeline

from sklearn.inspection import partial_dependence
from sklearn.inspection import plot_partial_dependence
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn import mixture
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler


# !pip install skorch
from skorch import NeuralNetClassifier
from sklearn.model_selection import cross_val_score
# Out:
# Requirement already satisfied: skorch in /usr/local/lib/python3.6/dist-packages (0.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from skorch) (1.18.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from skorch) (1.4.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from skorch) (0.8.7)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.6/dist-packages (from skorch) (4.41.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from skorch) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.19.1->skorch) (0.15.1)

# %% [markdown]
# # Load the dataset (2004 period)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ds = xr.open_dataset("/content/gdrive/My Drive/dataset/SST_SSH_U_V_SLA_global_2004.nc")
print(ds.sizes)
ds
# Out:
# Frozen(SortedKeysDict({'lon': 1440, 'lat': 720, 'time': 366}))
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 366)
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Data variables:
#     SST      (time, lat, lon) float32 ...
#     SSH      (time, lon, lat) float32 ...
#     U        (time, lon, lat) float32 ...
#     V        (time, lon, lat) float32 ...
#     SLA      (time, lon, lat) float32 ...
# Attributes:
#     CDI:                    Climate Data Interface version 1.5.3 (http://code...
#     Conventions:            CF-1.0
#     history:                Mon Jul 21 17:26:58 2014: cdo merge SST_SSH_U_V_g...
#     title:                  Analysed foundation sea surface temperature, global
#     DSD_entry_id:           REMSS-L4LRfnd-GLOB-tmi_amsre_OI
#     references:             none
#     source_data:            TMI-REMSS,AMSRE-REMSS
#     contact:                support@remss.com
#     GDS_version_id:         GDS-v1.0-rev1.6
#     netcdf_version_id:      3.5.0
#     creation_date:          2010-08-04
#     product_version:        v03
#     spatial_resolution:     25 km
#     start_date:             2003-12-30
#     start_time:             00:00:00 UTC
#     stop_date:              2004-01-03
#     stop_time:              23:59:59 UTC
#     southernmost_latitude:  -89.875
#     northernmost_latitude:  89.875
#     westernmost_longitude:  -179.875
#     easternmost_longitude:  179.875
#     file_quality_index:     1
#     comment:                www.remss.com for more infomation on product
#     CDO:                    Climate Data Operators version 1.5.3 (http://code...

# %%
time_window = 120

ds_cut = ds.sel(lon=slice(30,42),lat=slice(-48,-30))
ds_cut = ds_cut.isel(time=slice(0,time_window))
SSH = ds_cut.SSH.transpose('time','lat','lon')
SSH[0].plot()
SSH
# Out:
# <xarray.DataArray 'SSH' (time: 120, lat: 72, lon: 48)>
# [414720 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 30.125 30.375 30.625 30.875 ... 41.375 41.625 41.875
#   * lat      (lat) float32 -47.875 -47.625 -47.375 ... -30.625 -30.375 -30.125
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 2004-04-29T12:00:00
# Attributes:
#     long_name:        H
#     units:            cm
#     _CoordinateAxes:  time NbLongitudes NbLatitudes

# %%
SST = ds_cut.SST
SST[0].plot()

# %%
SSH[110].plot()

# %%
U = ds_cut.U.transpose('time','lat','lon')
V = ds_cut.V.transpose('time','lat','lon')
UV = U + V
UV[0].plot()

# %%
df = ds_cut.to_dataframe()
SST_x_max = df.SST.describe(include='all').loc['max']
SST_x_min = df.SST.describe(include='all').loc['min']
SSH_x_max = df.SSH.describe(include='all').loc['max']
SSH_x_min = df.SSH.describe(include='all').loc['min']
U_x_max = df.U.describe(include='all').loc['max']
U_x_min = df.U.describe(include='all').loc['min']
V_x_max = df.V.describe(include='all').loc['max']
V_x_min = df.V.describe(include='all').loc['min']
df.describe()
# Out:
#                  SST            SSH  ...              V            SLA
# count  405000.000000  414120.000000  ...  413640.000000  414720.000000
# mean      290.646210      68.459991  ...       0.222889       6.277696
# std         6.365062      54.519394  ...      25.368128      19.130518
# min       276.750000     -62.506332  ...    -156.930954     -83.590195
# 25%       284.399994      12.988934  ...      -7.640310      -2.466063
# 50%       293.100006      83.187851  ...       0.802993       4.450123
# 75%       295.949982     118.468697  ...       9.747392      13.739470
# max       302.100006     199.925827  ...     120.398727      89.636559
#
# [8 rows x 5 columns]

# %%
for v in ds_cut.data_vars:
    print('{:>10}: {}'.format(v, ds[v].attrs['long_name']))
# Out:
#        SST: analysed sea surface temperature
#        SSH: H
#          U: U
#          V: V
#        SLA: H

# %% [markdown]
# #Normalization

# %%
def pad_with(vector, pad_width, iaxis, kwargs):
  pad_value = kwargs.get('padder', 10)
  vector[:pad_width[0]] = pad_value
  vector[-pad_width[1]:] = pad_value

def normalize_negative_one(img):
    normalized_input = (img - np.amin(img)) / (np.amax(img) - np.amin(img))
    return 2*normalized_input - 1

# %%
from sklearn.feature_extraction import image


#fill NaN values with the mean of the SSH, SST, U, V mean
SSTf = SST.fillna(SST.mean())
#SSTf = np.pad(SSTf, padding, pad_with, padder=SSTf.mean())
print('SST shape: {}'.format(SSTf.shape))


SSHf = SSH.fillna(SSH.mean())
print('SSH shape: {}'.format(SSHf.shape))

Uf = U.fillna(U.mean())
print('U shape: {}'.format(Uf.shape))

Vf = V.fillna(V.mean())
print('V shape: {}'.format(Vf.shape))

SST_n = np.empty(([time_window, 72,48]))
SSH_n = np.empty(([time_window, 72,48]))
U_n = np.empty(([time_window, 72,48]))
V_n = np.empty(([time_window, 72,48]))
#for each time step, compute patches of size (13x13), flatten them in 1D and concatenate them in SSH_patches, SST_patches, U_patches, V_patches
#output : 1D array of SSH patchs
for i in range(ds_cut.time.shape[0]):
  if (i%50 == 0):
    print("Round : "+ str(i))
  
  #print(SSH.shape[0])
  #for h in range(SSH[0].shape[0]):
  SSH_n[i] = (SSHf[i] - SSH_x_min)/(SSH_x_max-SSH_x_min)
  U_n[i] = (Uf[i] - U_x_min)/(U_x_max-U_x_min)
  V_n[i] = (Vf[i] - V_x_min)/(V_x_max-V_x_min)
  SST_n[i] = (SSTf[i] - SST_x_min)/(SST_x_max-SST_x_min)
  

  #print("SST " + str(SST[i].shape))
# Out:
# SST shape: (120, 72, 48)
# SSH shape: (120, 72, 48)
# U shape: (120, 72, 48)
# V shape: (120, 72, 48)
# Round : 0
# Round : 50
# Round : 100

# %%
## compute accuracy
def get_accuracy(logit, target, batch_size):
    ''' Obtain accuracy for training round '''
    corrects = (torch.max(logit, 1)[1].view(target.size()).data == target.data).sum()
    accuracy = 100.0 * corrects/batch_size
    return accuracy.item()

# %%
def calculate_accuracy(Y_hat, Y):
     _, Y_hat = Y_hat.max(1)
    print("Y : " + str(Y.shape))
    print("Y_hat : " + str(Y_hat.shape))
    trues = (Y_hat == Y[:,0,:,:].long()) * 1
    trues = trues.cpu().numpy()

    accuracy = np.mean(trues)

    return accuracy, Y_hat.cpu().numpy(), Y.cpu().numpy()


def evaluate_set(model, data_loader, set_name):
    model.eval()

    average_accuracy = 0
    n_samples = 0

    y_true = []
    y_pred = []

    for batch_idx, batch in enumerate(data_loader):
        print(str(batch_idx) + " / " + str(len(data_loader)))
        X = batch[0]
        Y = batch[1]

        batch_size = Y.shape[0]
        n_samples += batch_size

        out = model(X)

        accuracy, Y_hat, Y = calculate_accuracy(out, Y)
        average_accuracy += accuracy * batch_size

        y_true.append(Y)
        y_pred.append(Y_hat)

    return average_accuracy / n_samples, y_true, y_pred

# %%
class ConvNet(torch.nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = torch.nn.Sequential(torch.nn.Conv2d(3, 3, kernel_size=3, stride=1, dilation = 1, padding=1))
        self.cnn_layers = Sequential(
            # Defining a 2D convolution layer
            torch.nn.Conv2d(3, 3, kernel_size=3, stride=1, dilation = 1, padding=1),
            ReLU(inplace=True)
        )

        
    def forward(self, x):
      out1 = self.layer1(x)
      #out1 = self.cnn_layers(x)
      #out2 = self.fc1(out1)
      return out1

# %%
#X = np.stack((SST_patches,SSH, U, V))
X= SST_n
print(X[0].shape)

BATCH_SIZE = 90

print("U : " + str(U_n.shape))
print("V : " + str(V_n.shape))
print("SSH : " + str(SSH_n.shape))
y = np.stack((SSH_n, U_n, V_n)) 
y_nb_feature = y.shape[0]
#print magique
print(SST.shape[2])

y = y.reshape((time_window, SSH_n.shape[1], SSH_n.shape[2],y_nb_feature))
print("Y shape :" + str(y.shape))
# Split the data into training/testing sets
X_train_np_1 = X[:90]
X_train_np = X[:70]
X_val_np = X[-20:]
X_test_np = X[-30:]
#X_train_rsp = X_train_np.reshape((190, 1, 72, 48))

X_train_exp = np.expand_dims(X_train_np,1)
X_train_dup = torch.from_numpy(X_train_exp).double()
X_train = X_train_dup.repeat(1,3,1,1)

X_val_exp = np.expand_dims(X_val_np,1)
X_val_dup = torch.from_numpy(X_val_exp).double()
X_val = X_val_dup.repeat(1,3,1,1)

X_test_exp = np.expand_dims(X_test_np,1)
X_test_dup = torch.from_numpy(X_test_exp).double()
X_test = X_test_dup.repeat(1,3,1,1)

print(type(X_train))
# Split the targets into training/testing sets
y_train_np_1 = y[:90]
y_train_np = y_train_np_1[:70]
y_val_np = y[-20:]
y_test_np = y[-30:]

y_train_rp = y_train_np.reshape((70, 3, 72, 48))
y_val_rp = y_val_np.reshape((20, 3, 72, 48))
y_test_rp = y_test_np.reshape((30, 3, 72, 48))

y_train = torch.from_numpy(y_train_rp).double()
y_val = torch.from_numpy(y_val_rp).double()
y_test = torch.from_numpy(y_test_rp).double()

#train = torch.utils.data.TensorDataset(X_train,y_train)

train_loader = DataLoader([X_train,y_train], batch_size=70, shuffle=True)
val_loader = DataLoader([X_val,y_val], batch_size=20, shuffle=True)
test_loader = DataLoader([X_test,y_test], batch_size=30, shuffle=False)

print("X_train : " + str(X_train.shape))
print("y_train : " + str(y_train.shape))
print("X_val : " + str(X_val.shape))
print("y_val : " + str(y_val.shape))
print("X_test : " + str(X_test.shape))
print("y_test : " + str(y_test.shape))


# Hyperparameters
num_epochs = 50
batch_size = 70
learning_rate = 0.01


#torch.manual_seed(RANDOM_SEED)

model = ConvNet()
model = model.double()

#model = ConvNet()
#model = model.double()
# Loss and optimizer
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

total_step = len(train_loader)
loss_list = []
acc_list = []
lap_list = []
val_list = []
for epoch in range(num_epochs):
  running_loss = 0.0
  running_lap = 0.0
  print("Epoch : " + str(epoch))
  for i, (images, labels) in enumerate(train_loader):
    # Run the forward pass
    print(images.type())
    print(labels.type())
    outputs = model(images)
    print("output : " + str(outputs.shape))
    print("labels : " + str(labels.shape))
    loss = torch.sqrt(criterion(outputs, labels))

    lap_out = kornia.filters.laplacian(outputs,3)
    lap_lab = kornia.filters.laplacian(labels,3)
    lap = torch.sqrt(criterion(lap_out, lap_lab))

    loss_list.append(loss.item())
    lap_list.append(lap)

    # Backprop and perform Adam optimisation
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    running_lap += lap
    if i % 90 == 0: 
      print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss ))
      print('laplacian : ' + str(running_lap))
      plt.figure()
      plt.title('Prediction Train')
      plt.imshow(torch.exp(outputs[0,2,:,:]).detach().cpu(), label='OUTPUT')
      running_loss = 0.0

      with torch.no_grad():
            validation_accuracy, _, _ = evaluate_set(model,
                                                     val_loader,
                                                     "VAL")
      print("validation accuracy :" + str(validation_accuracy))
      val_list.append(validation_accuracy)
# Out:
# (72, 48)
# U : (120, 72, 48)
# V : (120, 72, 48)
# SSH : (120, 72, 48)
# 48
# Y shape :(120, 72, 48, 3)
# <class 'torch.Tensor'>
# X_train : torch.Size([70, 3, 72, 48])
# y_train : torch.Size([70, 3, 72, 48])
# X_val : torch.Size([20, 3, 72, 48])
# y_val : torch.Size([20, 3, 72, 48])
# X_test : torch.Size([30, 3, 72, 48])
# y_test : torch.Size([30, 3, 72, 48])
# Epoch : 0
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [1,     1] loss: 0.692
# laplacian : tensor(0.0305, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 1
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [2,     1] loss: 0.626
# laplacian : tensor(0.0253, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 2
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [3,     1] loss: 0.516
# laplacian : tensor(0.0311, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 3
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [4,     1] loss: 0.425
# laplacian : tensor(0.0299, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 4
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [5,     1] loss: 0.380
# laplacian : tensor(0.0239, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 5
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [6,     1] loss: 0.255
# laplacian : tensor(0.0268, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.012514467592592593
# Epoch : 6
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [7,     1] loss: 0.189
# laplacian : tensor(0.0252, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8193576388888889
# Epoch : 7
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [8,     1] loss: 0.253
# laplacian : tensor(0.0219, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9814814814814815
# Epoch : 8
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [9,     1] loss: 0.240
# laplacian : tensor(0.0228, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9858072916666668
# Epoch : 9
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [10,     1] loss: 0.237
# laplacian : tensor(0.0243, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.977242476851852
# Epoch : 10
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [11,     1] loss: 0.289
# laplacian : tensor(0.0295, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.986082175925926
# Epoch : 11
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [12,     1] loss: 0.326
# laplacian : tensor(0.0307, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9821903935185186
# Epoch : 12
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [13,     1] loss: 0.338
# laplacian : tensor(0.0309, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9873408564814815
# Epoch : 13
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [14,     1] loss: 0.331
# laplacian : tensor(0.0302, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9820601851851853
# Epoch : 14
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [15,     1] loss: 0.260
# laplacian : tensor(0.0258, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9922887731481481
# Epoch : 15
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [16,     1] loss: 0.284
# laplacian : tensor(0.0278, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.986574074074074
# Epoch : 16
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [17,     1] loss: 0.252
# laplacian : tensor(0.0263, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9593026620370371
# Epoch : 17
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [18,     1] loss: 0.239
# laplacian : tensor(0.0226, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9140914351851851
# Epoch : 18
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [19,     1] loss: 0.192
# laplacian : tensor(0.0238, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7564814814814815
# Epoch : 19
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [20,     1] loss: 0.169
# laplacian : tensor(0.0231, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.5945891203703704
# Epoch : 20
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [21,     1] loss: 0.156
# laplacian : tensor(0.0225, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.02165798611111111
# Epoch : 21
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [22,     1] loss: 0.158
# laplacian : tensor(0.0222, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.015813078703703704
# Epoch : 22
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [23,     1] loss: 0.262
# laplacian : tensor(0.0201, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.01362847222222222
# Epoch : 23
# torch.DoubleTensor
# torch.DoubleTensor
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:118: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [24,     1] loss: 0.269
# laplacian : tensor(0.0203, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0009403935185185186
# Epoch : 24
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [25,     1] loss: 0.271
# laplacian : tensor(0.0208, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 25
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [26,     1] loss: 0.219
# laplacian : tensor(0.0239, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 26
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [27,     1] loss: 0.267
# laplacian : tensor(0.0214, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.0
# Epoch : 27
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [28,     1] loss: 0.217
# laplacian : tensor(0.0238, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.001345486111111111
# Epoch : 28
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [29,     1] loss: 0.250
# laplacian : tensor(0.0209, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.006524884259259259
# Epoch : 29
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [30,     1] loss: 0.238
# laplacian : tensor(0.0205, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.014728009259259258
# Epoch : 30
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [31,     1] loss: 0.166
# laplacian : tensor(0.0219, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.022902199074074075
# Epoch : 31
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [32,     1] loss: 0.155
# laplacian : tensor(0.0211, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.6720630787037037
# Epoch : 32
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [33,     1] loss: 0.230
# laplacian : tensor(0.0192, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7793836805555555
# Epoch : 33
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [34,     1] loss: 0.233
# laplacian : tensor(0.0191, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8361979166666667
# Epoch : 34
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [35,     1] loss: 0.174
# laplacian : tensor(0.0201, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9631221064814814
# Epoch : 35
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [36,     1] loss: 0.225
# laplacian : tensor(0.0196, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8291666666666668
# Epoch : 36
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [37,     1] loss: 0.217
# laplacian : tensor(0.0201, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9578125
# Epoch : 37
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [38,     1] loss: 0.204
# laplacian : tensor(0.0218, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9500578703703704
# Epoch : 38
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [39,     1] loss: 0.209
# laplacian : tensor(0.0220, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.941015625
# Epoch : 39
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [40,     1] loss: 0.200
# laplacian : tensor(0.0216, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7065104166666667
# Epoch : 40
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [41,     1] loss: 0.208
# laplacian : tensor(0.0198, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.660792824074074
# Epoch : 41
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [42,     1] loss: 0.210
# laplacian : tensor(0.0193, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.7916956018518518
# Epoch : 42
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [43,     1] loss: 0.211
# laplacian : tensor(0.0190, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.037919560185185185
# Epoch : 43
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [44,     1] loss: 0.211
# laplacian : tensor(0.0189, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.025665509259259263
# Epoch : 44
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [45,     1] loss: 0.210
# laplacian : tensor(0.0190, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.01572627314814815
# Epoch : 45
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [46,     1] loss: 0.176
# laplacian : tensor(0.0199, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.011096643518518518
# Epoch : 46
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [47,     1] loss: 0.171
# laplacian : tensor(0.0194, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.013339120370370373
# Epoch : 47
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [48,     1] loss: 0.157
# laplacian : tensor(0.0183, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.03208912037037037
# Epoch : 48
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [49,     1] loss: 0.147
# laplacian : tensor(0.0170, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.8026331018518519
# Epoch : 49
# torch.DoubleTensor
# torch.DoubleTensor
# output : torch.Size([70, 3, 72, 48])
# labels : torch.Size([70, 3, 72, 48])
# [50,     1] loss: 0.150
# laplacian : tensor(0.0157, dtype=torch.float64, grad_fn=<AddBackward0>)
# 0 / 1
# Y : torch.Size([20, 3, 72, 48])
# Y_hat : torch.Size([20, 72, 48])
# validation accuracy :0.9077256944444445

# %%
print(outputs[0,0,:,:])
plt.figure()
plt.title('Prediction Train')
plt.imshow(torch.exp(outputs[0,0,:,:]).detach().cpu(), label='OUTPUT')
#plt.clim(-3, 3)
plt.colorbar(label = 'SSH value')
plt.figure()
plt.title('Input Train')
plt.imshow(torch.exp(images[0,0,:,:]).detach().cpu(), label='OUTPUT')
#plt.clim(-3, 3)
plt.colorbar(label = 'SSH value')
plt.figure()
plt.title('Label Train')
plt.imshow(torch.exp(y_train[0,0,:,:]).detach().cpu(), label='LABEL') 
#plt.clim(-3, 3)
plt.colorbar(label = 'SSH value')
plt.figure()
plt.title('RMSE Loss')
plt.plot(np.array(loss_list), 'r')

plt.figure()
plt.title('Laplacian')
plt.plot(np.array(lap_list), 'r')

plt.figure()
plt.title('Validation Set Accuracy')
plt.plot(np.array(val_list), 'r')
# Out:
# tensor([[0.1773, 0.1789, 0.1763,  ..., 0.1453, 0.1489, 0.1348],
#         [0.2201, 0.2083, 0.2032,  ..., 0.1597, 0.1650, 0.1459],
#         [0.2228, 0.2099, 0.2034,  ..., 0.1633, 0.1739, 0.1502],
#         ...,
#         [0.4789, 0.4680, 0.4680,  ..., 0.6147, 0.6171, 0.3796],
#         [0.4789, 0.4680, 0.4680,  ..., 0.6166, 0.6194, 0.3795],
#         [0.3581, 0.4465, 0.4465,  ..., 0.5867, 0.5895, 0.4939]],
#        dtype=torch.float64, grad_fn=<SliceBackward>)

# %%
with torch.no_grad():
      validation_accuracy, _, _ = evaluate_set(model,test_loader,"VAL")
      print("validation accuracy :" + str(validation_accuracy))
# Out:
# 0 / 1
# Y : torch.Size([30, 3, 72, 48])
# Y_hat : torch.Size([30, 72, 48])
# validation accuracy :0.6575906635802469

# %%
plt.figure()
plt.imshow(torch.exp(outputs_test[10,0,:,:]).detach().cpu())
plt.figure()
plt.imshow(torch.exp(lab[0,0,:,:]).detach().cpu())  # plot class1

# %%
plt.figure()
plt.imshow(torch.exp(outputs[20,0,:,:]).detach().cpu(), label='OUTPUT')

# %%
plt.figure()
plt.imshow(torch.exp(images[0,0,:,:]).detach().cpu(), label='LABEL')

# %%
plt.figure()
plt.imshow(torch.exp(X_train[0,0,:,:]).detach().cpu(), label='LABEL')

# %%
plt.plot(np.array(loss_list), 'r')

# %%
SST[0].plot()
print(SSH_n[0])
# Out:
# [[0.21693842 0.21472597 0.21338467 ... 0.09762648 0.10520961 0.1108307 ]
#  [0.23600033 0.22473978 0.2170475  ... 0.10763428 0.11932342 0.12951872]
#  [0.25110143 0.2340114  0.22354679 ... 0.12446788 0.13773222 0.14990127]
#  ...
#  [0.49904889 0.62908685 0.55243802 ... 0.61563939 0.61169457 0.61985147]
#  [0.49904889 0.67119944 0.57574224 ... 0.62275892 0.61220044 0.61576819]
#  [0.49904889 0.49904889 0.49904889 ... 0.63112634 0.61427557 0.61374074]]

# %%
def train(epoch):
    model.train()
    tr_loss = 0
    # getting the training set
    x_train, y_train = Variable(train_x), Variable(train_y)
    # getting the validation set
    x_val, y_val = Variable(val_x), Variable(val_y)
    # converting the data into GPU format
    if torch.cuda.is_available():
        x_train = x_train.cuda()
        y_train = y_train.cuda()
        x_val = x_val.cuda()
        y_val = y_val.cuda()

    # clearing the Gradients of the model parameters
    optimizer.zero_grad()
    
    # prediction for training and validation set
    output_train = model(x_train)
    output_val = model(x_val)

    # computing the training and validation loss
    loss_train = criterion(output_train, y_train)
    loss_val = criterion(output_val, y_val)
    train_losses.append(loss_train)
    val_losses.append(loss_val)

    # computing the updated weights of all the model parameters
    loss_train.backward()
    optimizer.step()
    tr_loss = loss_train.item()
    if epoch%2 == 0:
        # printing the validation loss
        print('Epoch : ',epoch+1, '\t', 'loss :', loss_val)
